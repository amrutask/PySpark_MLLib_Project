# %%
# from pyspark.sql import SparkSession
# spark = SparkSession.builder.appName("DataFrame_project").getOrCreate()
# already created in Databricks
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.172.240.61:45381">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
data = spark.read.csv("/FileStore/tables/walmart_stock.csv", inferSchema = True, header= True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [&#39;Date&#39;, &#39;Open&#39;, &#39;High&#39;, &#39;Low&#39;, &#39;Close&#39;, &#39;Volume&#39;, &#39;Adj Close&#39;]</div>

# %%
data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Date: timestamp (nullable = true)
# -- Open: double (nullable = true)
# -- High: double (nullable = true)
# -- Low: double (nullable = true)
# -- Close: double (nullable = true)
# -- Volume: integer (nullable = true)
# -- Adj Close: double (nullable = true)
#
# </div>

# %%
data.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: [Row(Date=datetime.datetime(2012, 1, 3, 0, 0), Open=59.970001, High=61.060001, Low=59.869999, Close=60.330002, Volume=12668800, Adj Close=52.619234999999996),
#  Row(Date=datetime.datetime(2012, 1, 4, 0, 0), Open=60.209998999999996, High=60.349998, Low=59.470001, Close=59.709998999999996, Volume=9593300, Adj Close=52.078475),
#  Row(Date=datetime.datetime(2012, 1, 5, 0, 0), Open=59.349998, High=59.619999, Low=58.369999, Close=59.419998, Volume=12768200, Adj Close=51.825539),
#  Row(Date=datetime.datetime(2012, 1, 6, 0, 0), Open=59.419998, High=59.450001, Low=58.869999, Close=59.0, Volume=8069400, Adj Close=51.45922),
# ...

# %%
desc = data.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# summary|              Open|             High|              Low|            Close|           Volume|        Adj Close|
# +-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
#   count|              1258|             1258|             1258|             1258|             1258|             1258|
#    mean| 72.35785375357709|72.83938807631165| 71.9186009594594|72.38844998012726|8222093.481717011|67.23883848728146|
# ...

# %%
from pyspark.sql.functions import format_number
desc.select(desc['summary'], 
                  format_number(desc['Open'].cast('float'),2).alias('Open'), 
                  format_number(desc['High'].cast('float'),2).alias('High'), 
                  format_number(desc['Low'].cast('float'), 2).alias('Low'),
                  format_number(desc['Close'].cast('float'), 2).alias('Close'),
                  format_number(desc['Volume'].cast('float'),2).alias('Volume'), 
                  format_number(desc['Adj Close'].cast('float'), 2).alias('Adj Close')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+--------+--------+--------+-------------+---------+
# summary|    Open|    High|     Low|   Close|       Volume|Adj Close|
# +-------+--------+--------+--------+--------+-------------+---------+
#   count|1,258.00|1,258.00|1,258.00|1,258.00|     1,258.00| 1,258.00|
#    mean|   72.36|   72.84|   71.92|   72.39| 8,222,093.50|    67.24|
#  stddev|    6.77|    6.77|    6.74|    6.76| 4,519,781.00|     6.72|
#     min|   56.39|   57.06|   56.30|   56.42| 2,094,900.00|    50.36|
#     max|   90.80|   90.97|   89.25|   90.47|80,898,096.00|    84.91|
# +-------+--------+--------+--------+--------+-------------+---------+
#
# ...

# %%
df= data.withColumn("HV Ratio", data['High']/data['Volume']).show()
df.select('HV Ratio').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#             HV Ratio|
# +--------------------+
# 4.819714653321546E-6|
# 6.290848613094555E-6|
# 4.669412994783916E-6|
# 7.367338463826307E-6|
# 8.915604778943901E-6|
# 8.644477436914568E-6|
# 9.351828421515645E-6|
#  8.29141562102703E-6|
# 7.712212102001476E-6|
# 7.071764823529412E-6|
# 1.015495466386981E-5|
# 6.576354146362592...|
#  5.90145296180676E-6|
# 8.547679455011844E-6|
# 8.420709512685392E-6|
# 1.041448341728929...|
# 8.316075414862431E-6|
# 9.721183814992126E-6|
# 8.029436027707578E-6|
# 6.307432259386365E-6|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
data.orderBy(df['High'].desc()).head(1)[0][0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: datetime.datetime(2015, 1, 13, 0, 0)</div>

# %%
from pyspark.sql.functions import mean
data.select(mean('Close')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(Close)|
# +-----------------+
# 72.38844998012726|
# +-----------------+
#
# </div>

# %%
from pyspark.sql.functions import max, min

data.select(max('Volume'), min('Volume')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+
# max(Volume)|min(Volume)|
# +-----------+-----------+
#    80898100|    2094900|
# +-----------+-----------+
#
# </div>

# %%
data.filter('close < 60').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: 81</div>

# %%
data.filter(data['Close']< 60).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: 81</div>

# %%
from pyspark.sql.functions import count

data.select('High').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: 1258</div>

# %%
data.filter('High > 80').count() / data.select('High').count() * 100
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: 9.141494435612083</div>

# %%
from pyspark.sql.functions import corr

data.select(corr('High', 'Volume')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
#  corr(High, Volume)|
# +-------------------+
# -0.3384326061737161|
# +-------------------+
#
# </div>

# %%
#part 1
from pyspark.sql.functions import year

yeardf = data.withColumn("Year", year(data['Date']))
yeardf.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+------------------+------------------+------------------+------------------+--------+------------------+----+
#                Date|              Open|              High|               Low|             Close|  Volume|         Adj Close|Year|
# +-------------------+------------------+------------------+------------------+------------------+--------+------------------+----+
# 2012-01-03 00:00:00|         59.970001|         61.060001|         59.869999|         60.330002|12668800|52.619234999999996|2012|
# ...

# %%
#Part 2

max_df= yeardf.groupBy('Year').max()
max_df.select('Year', 'max(High)').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+---------+
# Year|max(High)|
# +----+---------+
# 2015|90.970001|
# 2013|81.370003|
# 2014|88.089996|
# 2012|77.599998|
# 2016|75.190002|
# +----+---------+
#
# </div>

# %%
from pyspark.sql.functions import month
month_df = data.withColumn('Month', month(data['Date']))
mean_df= month_df.groupBy('Month').mean()
mean_df.select('Month', 'avg(Close)').orderBy('Month').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----------------+
# Month|       avg(Close)|
# +-----+-----------------+
#     1|71.44801958415842|
#     2|  71.306804443299|
#     3|71.77794377570092|
#     4|72.97361900952382|
#     5|72.30971688679247|
#     6| 72.4953774245283|
#     7|74.43971943925233|
#     8|73.02981855454546|
#     9|72.18411785294116|
#    10|71.57854545454543|
#    11| 72.1110893069307|
#    12|72.84792478301885|
# +-----+-----------------+
#
# </div>
